# %%
from mpl_toolkits.basemap import Basemap, shiftgrid, cm
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset
# %matplotlib inline

# %%
# read in etopo5 topography/bathymetry.
url = 'http://ferret.pmel.noaa.gov/thredds/dodsC/data/PMEL/etopo5.nc'
etopodata = Dataset(url)

# get variable (ROSE), lat and lon
topoin = etopodata.variables['ROSE'][:]
lons = etopodata.variables['ETOPO05_X'][:]
lats = etopodata.variables['ETOPO05_Y'][:]
# shift data so lons go from -180 to 180 instead of 20 to 380.
topoin,lons = shiftgrid(180.,topoin,lons,start=False)

# %%
# make plot

# create the figure and axes instances
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8])

# setup of basemap; note here that each projection has a different set of arguments
#  see https://matplotlib.org/basemap/users/mapsetup.html for details
#  1) 'merc' = mercator projection
#  2) define region to be Hawaiian Islands; "merc" projection takes the corners
#     of the map as lower left corner latitude and longitude (llcrnrlat,llcrnrlon)
#     and upper right corner latitude and longitude (urcrnrlat,urcrnrlon)
#  3) lat_ts is the latitude of true scale; just define this as midpoint
#  4) resolution is like GMT low (l), crude (c), high (h), full (f)
lon1 = -175.0
lat1 = 15.0
lon2 = -150.0
lat2 = 30.0
lat_ts = ( lat2 - lat1) / 2.0

# use major and minor sphere radii from WGS84 ellipsoid.
m = Basemap( llcrnrlon = lon1, llcrnrlat = lat1, urcrnrlon = lon2, urcrnrlat = lat2,\
             lat_ts = lat_ts, resolution = 'h', ax = ax )
#            rsphere=(6378137.00,6356752.3142),\
#            resolution='l',area_thresh=1000.,projection='lcc',\
#            lat_1=20.,lon_0=-162.,ax=ax)
m.etopo()

# %%
# use major and minor sphere radii from WGS84 ellipsoid.
m = Basemap( llcrnrlon = lon1, llcrnrlat = lat1, urcrnrlon = lon2, urcrnrlat = lat2,\
            rsphere=(6378137.00,6356752.3142),\
            resolution='l',area_thresh=1000.,projection='lcc',\
            lat_1=20.,lon_0=-162.,ax=ax)
# display the image

# transform to nx x ny regularly spaced 5km native projection grid
nx = int((m.xmax-m.xmin)/5000.)+1; ny = int((m.ymax-m.ymin)/5000.)+1
topodat = m.transform_scalar(topoin,lons,lats,nx,ny)

# plot image over map with imshow.
im = m.imshow(topodat,cm.GMT_haxby)

# draw coastlines and political boundaries.
m.drawcoastlines()
m.drawcountries()
m.drawstates()

# draw parallels and meridians.
# label on left and bottom of map.
parallels = np.arange(0.,80,20.)
m.drawparallels(parallels,labels=[1,0,0,1])
meridians = np.arange(10.,360.,30.)
m.drawmeridians(meridians,labels=[1,0,0,1])

# add colorbar
cb = m.colorbar(im,"right", size="5%", pad='2%')
ax.set_title('ETOPO5 Topography - Lambert Conformal Conic')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-10ce1d48c368> in <module>
#      26
#      27 # add colorbar
# ---> 28 cb = m.colorbar(im,"right", size="5%", pad='2%')
#      29 ax.set_title('ETOPO5 Topography - Lambert Conformal Conic')
#
# /anaconda3/lib/python3.7/site-packages/mpl_toolkits/basemap/__init__.py in colorbar(self, mappable, location, size, pad, fig, ax, **kwargs)
#    4604         # create colorbar.
#    4605         cb = fig.colorbar(mappable,orientation=orientation,cax=cax,**kwargs)
# -> 4606         fig.sca(ax) # reset parent axes as current axes.
#    4607         return cb
#    4608
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in sca(self, a)
#    1865     def sca(self, a):
#    1866         """Set the current axes to be a and return a."""
# -> 1867         self._axstack.bubble(a)
#    1868         for func in self._axobservers:
#    1869             func(self)
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in bubble(self, a)
#     116         stack, to the top.
#     117         """
# --> 118         return Stack.bubble(self, self._entry_from_axes(a))
#     119
#     120     def add(self, key, a):
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in _entry_from_axes(self, e)
#     104
#     105     def _entry_from_axes(self, e):
# --> 106         ind, k = {a: (ind, k) for k, (ind, a) in self._elements}[e]
#     107         return (k, (ind, e))
#     108
#
# KeyError: <matplotlib.axes._axes.Axes object at 0x10d4c59e8>

# %%
m = Basemap(width=12000000,height=9000000,projection='lcc',
            resolution=None,lat_1=lat1,lat_2=lat2,lat_0=lon1,lon_0=lon2)
m.etopo()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-a136e6178392> in <module>
#       1 m = Basemap(width=12000000,height=9000000,projection='lcc',
# ----> 2             resolution=None,lat_1=lat1,lat_2=lat2,lat_0=lon1,lon_0=lon2)
#       3 m.etopo()
#
# /anaconda3/lib/python3.7/site-packages/mpl_toolkits/basemap/__init__.py in __init__(self, llcrnrlon, llcrnrlat, urcrnrlon, urcrnrlat, llcrnrx, llcrnry, urcrnrx, urcrnry, width, height, projection, resolution, area_thresh, rsphere, ellps, lat_ts, lat_1, lat_2, lat_0, lon_0, lon_1, lon_2, o_lon_p, o_lat_p, k_0, no_rot, suppress_ticks, satellite_height, boundinglat, fix_aspect, anchor, celestial, round, epsg, ax)
#     696         projparams['units']='m'
#     697         # check for sane values of lon_0, lat_0, lat_ts, lat_1, lat_2
# --> 698         lat_0 = _validated_or_none(lat_0, 'lat_0', -90, 90)
#     699         lat_1 = _validated_or_none(lat_1, 'lat_1', -90, 90)
#     700         lat_2 = _validated_or_none(lat_2, 'lat_2', -90, 90)
#
# /anaconda3/lib/python3.7/site-packages/mpl_toolkits/basemap/__init__.py in _validated_or_none(param, name, minval, maxval)
#     524     if param is None:
#     525         return None
# --> 526     return _validated_ll(param, name, minval, maxval)
#     527
#     528
#
# /anaconda3/lib/python3.7/site-packages/mpl_toolkits/basemap/__init__.py in _validated_ll(param, name, minval, maxval)
#     517     if param > maxval or param < minval:
#     518         raise ValueError('%s must be between %f and %f degrees' %
# --> 519                                            (name, minval, maxval))
#     520     return param
#     521
#
# ValueError: lat_0 must be between -90.000000 and 90.000000 degrees
